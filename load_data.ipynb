# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#load the dataset
import kagglehub

# Download latest version
path = kagglehub.dataset_download("altavish/boston-housing-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\ENVY\.cache\kagglehub\datasets\altavish\boston-housing-dataset\versions\1

# %%
import os
print(os.listdir(path))
# Out:
# ['HousingData.csv']

# %%
file_path = os.path.join(path, 'HousingData.csv')
boston= pd.read_csv(file_path)

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
boston.shape
# Out:
# (506, 14)

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
#Preparing the dataset
dataset = pd.DataFrame(boston)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset['LSTAT'].isna().sum()
dataset['LSTAT'].fillna(dataset['LSTAT'].median(), inplace=True)
# Out:
# C:\Users\ENVY\AppData\Local\Temp\ipykernel_22100\2788962260.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['LSTAT'].fillna(dataset['LSTAT'].median(), inplace=True)

# %%
dataset['Price'] = dataset.MEDV * 1000
dataset.drop('MEDV', axis=1, inplace=True)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT    Price
# 0  396.90   4.98  24000.0
# 1  396.90   9.14  21600.0
# 2  392.83   4.03  34700.0
# 3  394.63   2.94  33400.0
# 4  396.90  11.43  36200.0

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(dataset['Price'],kde=True)
plt.xlabel("Price in $")
plt.ylabel('Frequency')
plt.title("Distribution of House Prices")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dataset.corr(),cmap='coolwarm',annot=True)
plt.title("Correlation between different features")
plt.show()

# %%
features = ['RM','LSTAT','PTRATIO']
for col in features:
  plt.figure(figsize=(10,6))
  sns.scatterplot(x=dataset[col],y=dataset['Price'])
  plt.title(f"{col} VS Price")
  plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso,ElasticNet
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
X = pd.DataFrame(dataset.drop('Price',axis=1))
y = dataset['Price']

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24000.0
# 1      21600.0
# 2      34700.0
# 3      33400.0
# 4      36200.0
#         ...
# 501    22400.0
# 502    20600.0
# 503    23900.0
# 504    22000.0
# 505    11900.0
# Name: Price, Length: 506, dtype: float64

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  11.43
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0    NaN   0.0  0.510  6.416    NaN  2.6463    5  296
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# ...

# %%
y_train
# Out:
# 5      28700.0
# 116    21200.0
# 45     19300.0
# 16     23100.0
# 468    19100.0
#         ...
# 106    19500.0
# 270    21100.0
# 348    24500.0
# 435    13400.0
# 102    18600.0
# Name: Price, Length: 354, dtype: float64

# %%
y_test
# Out:
# 173    23600.0
# 274    32400.0
# 491    13600.0
# 72     22800.0
# 452    16100.0
#         ...
# 441    17100.0
# 23     14500.0
# 225    50000.0
# 433    14300.0
# 447    12600.0
# Name: Price, Length: 152, dtype: float64

# %%
X_train = X_train.dropna()
y_train = y_train[X_train.index]  # keep rows aligned
X_test = X_test.dropna()
y_test = y_test[X_test.index]

# %%
#Linear Regression Model
lr = LinearRegression()
lr.fit(X_train,y_train)
Y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test,Y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,Y_pred)
r2= r2_score(y_test,Y_pred)

# %%
mse,rmse,mae,r2
# Out:
# (22890614.49947835,
#  np.float64(4784.413704883636),
#  3093.2097756981457,
#  0.7127726674472109)

# %%
#Ridge Regression Model (Ridge Regression was used to address multicollinearity and reduce overfitting by applying L2 regularization, which penalizes large coefficients and minimizes the influence of high-variance, low-impact features.)
ridge_pipe = Pipeline([
  ("scaler", StandardScaler()),
  ("ridge",Ridge())
])

ridge_params = {
  "ridge__alpha":np.logspace(-3,3,50)
}

ridge_cv = GridSearchCV(ridge_pipe, ridge_params, cv=5, scoring='neg_mean_squared_error')
ridge_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('ridge', Ridge())]),
#              param_grid={'ridge__alpha': array([1.00000000e-03, 1.32571137e-03, 1.75751062e-03, 2.32995181e-03,
#        3.08884360e-03, 4.09491506e-03, 5.42867544e-03, 7.19685673e-03,
#        9.54095476e-03, 1.26485522e-02, 1.67683294e-02, 2.22299648e-02,
#        2.94705170e-02, 3.90693994e-02, 5.17947468e-02...
#        2.68269580e+00, 3.55648031e+00, 4.71486636e+00, 6.25055193e+00,
#        8.28642773e+00, 1.09854114e+01, 1.45634848e+01, 1.93069773e+01,
#        2.55954792e+01, 3.39322177e+01, 4.49843267e+01, 5.96362332e+01,
#        7.90604321e+01, 1.04811313e+02, 1.38949549e+02, 1.84206997e+02,
#        2.44205309e+02, 3.23745754e+02, 4.29193426e+02, 5.68986603e+02,
#        7.54312006e+02, 1.00000000e+03])},
#              scoring='neg_mean_squared_error')

# %%
y_pred_ridge = ridge_cv.predict(X_test)
ridge_mse = mean_squared_error(y_test,y_pred_ridge)
ridge_rmse = np.sqrt(ridge_mse)
ridge_mae = mean_absolute_error(y_test,y_pred_ridge)
ridge_r2= r2_score(y_test,y_pred_ridge)

# %%
ridge_mse, ridge_rmse, ridge_mae, ridge_r2
# Out:
# (23560100.978282023,
#  np.float64(4853.874841637557),
#  3098.1567578827867,
#  0.704372070971685)

# %%
lasso_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("lasso", Lasso(max_iter=10000))
])

lasso_params = {
    "lasso__alpha": np.logspace(-3, 1, 50)
}

lasso_cv = GridSearchCV(
    lasso_pipe,
    lasso_params,
    cv=5,
    scoring="neg_root_mean_squared_error"
)

lasso_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('lasso', Lasso(max_iter=10000))]),
#              param_grid={'lasso__alpha': array([1.00000000e-03, 1.20679264e-03, 1.45634848e-03, 1.75751062e-03,
#        2.12095089e-03, 2.55954792e-03, 3.08884360e-03, 3.72759372e-03,
#        4.49843267e-03, 5.42867544e-03, 6.55128557e-03, 7.90604321e-03,
#        9.54095476e-03, 1.15139540e-02,...
#        1.93069773e-01, 2.32995181e-01, 2.81176870e-01, 3.39322177e-01,
#        4.09491506e-01, 4.94171336e-01, 5.96362332e-01, 7.19685673e-01,
#        8.68511374e-01, 1.04811313e+00, 1.26485522e+00, 1.52641797e+00,
#        1.84206997e+00, 2.22299648e+00, 2.68269580e+00, 3.23745754e+00,
#        3.90693994e+00, 4.71486636e+00, 5.68986603e+00, 6.86648845e+00,
#        8.28642773e+00, 1.00000000e+01])},
#              scoring='neg_root_mean_squared_error')

# %%
y_pred_lasso = lasso_cv.predict(X_test)
lasso_mse = mean_squared_error(y_test,y_pred_lasso)
lasso_rmse = np.sqrt(lasso_mse)
lasso_mae = mean_absolute_error(y_test,y_pred_lasso)
lasso_r2= r2_score(y_test,y_pred_lasso)

# %%
lasso_mse, lasso_rmse, lasso_mae, lasso_r2
# Out:
# (22896747.302874535,
#  np.float64(4785.054576791631),
#  3092.6157504165276,
#  0.7126957141281728)

# %%
enet_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("enet", ElasticNet(max_iter=10000))
])

enet_params = {
    "enet__alpha": np.logspace(-3, 1, 20),
    "enet__l1_ratio": [0.2, 0.5, 0.8]
}

enet_cv = GridSearchCV(
    enet_pipe,
    enet_params,
    cv=5,
    scoring="neg_root_mean_squared_error"
)

enet_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('enet', ElasticNet(max_iter=10000))]),
#              param_grid={'enet__alpha': array([1.00000000e-03, 1.62377674e-03, 2.63665090e-03, 4.28133240e-03,
#        6.95192796e-03, 1.12883789e-02, 1.83298071e-02, 2.97635144e-02,
#        4.83293024e-02, 7.84759970e-02, 1.27427499e-01, 2.06913808e-01,
#        3.35981829e-01, 5.45559478e-01, 8.85866790e-01, 1.43844989e+00,
#        2.33572147e+00, 3.79269019e+00, 6.15848211e+00, 1.00000000e+01]),
#                          'enet__l1_ratio': [0.2, 0.5, 0.8]},
#              scoring='neg_root_mean_squared_error')

# %%
y_pred_enet = enet_cv.predict(X_test)
enet_mse = mean_squared_error(y_test,y_pred_enet)
enet_rmse = np.sqrt(enet_mse)
enet_mae = mean_absolute_error(y_test,y_pred_enet)
enet_r2= r2_score(y_test,y_pred_enet)

# %%
enet_mse, enet_rmse, enet_mae, enet_r2
# Out:
# (23546045.30032991,
#  np.float64(4852.426743427448),
#  3097.065222865929,
#  0.7045484391021911)

# %%
boston.data[0].reshape(1, -1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22100\26401456.py in ?()
# ----> 1 boston.data[0].reshape(1, -1)
#
# c:\Users\ENVY\OneDrive\Desktop\House_price_prediction\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
first_house = X.iloc[0, :].values.reshape(1, -1)
enet_cv.predict(first_house)
# Out:
# c:\Users\ENVY\OneDrive\Desktop\House_price_prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29467.83618341])
